# %% [markdown]
# # Detecting Human Faces
#
# Before anything else, a PiCamera has to be connected to the Raspberry Pi.
#
# In this notebook, we are using pre-trained Haar-Cascade classifiers for human faces and eyes. These pretrained classifiers which come with `opencv` are stored in an XML format.

# %%
import picamera
from picamera import PiCamera
import matplotlib.pyplot as plt
from picamera.array import PiRGBArray
import numpy as np
import cv2 as cv
import IPython
import io
import time
from PIL import Image

# %% [markdown]
# Since we are reading a continuous stream of RGB photos taken from the video port, we also need to display them continuously. For this matter we need the following function to do this.

# %%
# Use 'jpeg' instead of 'png' (~5 times faster)
def showarray(a, fmt='jpeg'):
    '''
    Function to display an image within a Jupyter notebook.
    '''
    im_array = np.asarray(a)
    plt.imshow(im_array)
    plt.show()

# %% [markdown]
# Now, let's load up the classifiers for eyes and faces. These 2 files should be located in the current directory.

# %%
body_cascade = cv.CascadeClassifier('haarcascade_upperbody.xml')
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_alt.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')

# %% [markdown]
# The following function is used to detect the human faces and eyes. `detectMultiScale` returns a list of coordinates where it detected something and if there's something, then it proceeds drawing green and red rectangles around the detected features. The image that now contains these red/green boxes is returned to where it got called.

# %%
def detectFacesAndEyes(img_array):
    '''
    Function to detect eyes and faces using a Haar-Cascade classifier.
    '''
    gray = cv.cvtColor(img_array, cv.COLOR_BGR2GRAY)
    body = body = body_cascade.detectMultiScale(gray,scaleFactor = 1.01,minNeighbors = 5,flags = cv.CASCADE_SCALE_IMAGE)
    for (x,y,w,h) in body:
        cv.rectangle(img_array,(x,y),(x+w,y+h),(0,0,255),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img_array[y:y+h, x:x+w]
        faces = face_cascade.detectMultiScale(roi_gray)
        for (fx,fy,fw,fh) in faces:
            cv.rectangle(roi_color,(fx,fy),(fx+fw,fy+fh),(0,255,0),2)
            roi_gray_face = roi_gray[y:y+h, x:x+w]
            roi_color_face = roi_color[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray_face)
            for (ex,ey,ew,eh) in eyes:
                cv.rectangle(roi_color_face,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)

# %% [markdown]
# Capture frames at the highest rate possible and on each frame run the Haar-Cascade detection system.
#
# Finally, on each iteration, the image gets to be displayed in JupyterLab.

# %%
# initialize the camera and grab a reference to the raw camera capture
camera = PiCamera()
camera.resolution = (320,240)
camera.framerate = 32
freshest_frame = PiRGBArray(camera, size=(320,240))

# allow the camera to warmup
time.sleep(0.1)


for frame in camera.capture_continuous(freshest_frame, format="rgb", use_video_port=True):
            img = frame.array
            
            detectFacesAndEyes(img)
            
            showarray(img)
            IPython.display.clear_output(wait = True)
            #cv.imshow("frame",img)
            #key = cv.waitKey(1) & 0xFF
            
            # clear the stream in preparation for the next frame
            freshest_frame.truncate(0)
            
            # if the `q` key was pressed, break from the loop
            #if key == ord("q"):
            #    break
                
            #showarray(freshest_frame)
            #IPython.display.clear_output(wait = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ea8fbd7bd5b4> in <module>()
#      14             detectFacesAndEyes(img)
#      15
# ---> 16             showarray(img)
#      17             IPython.display.clear_output(wait = True)
#      18             #cv.imshow("frame",img)
#
# <ipython-input-2-c1c46d6f3a1b> in showarray(a, fmt)
#       5     '''
#       6     im_array = np.asarray(a)
# ----> 7     plt.imshow(im_array)
#       8     plt.show()
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3187            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    3188            hold=None, data=None, **kwargs):
# -> 3189     ax = gca()
#    3190     # Deprecated: allow callers to override the hold state
#    3191     # by passing hold=True|False
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#     982     matplotlib.figure.Figure.gca : The figure's gca method.
#     983     """
# --> 984     return gcf().gca(**kwargs)
#     985
#     986 # More ways of creating axes:
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1815
#    1816         # no axes found, so create one which spans the figure
# -> 1817         return self.add_subplot(1, 1, 1, **kwargs)
#    1818
#    1819     def sca(self, a):
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      75
#      76         # _axes_class is set in the subplot_class_factory
# ---> 77         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      78         # add a layout box to this, for both the full axis, and the poss
#      79         # of the axis.  We need both because the axes may become smaller
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     504         self.set_axes_locator(kwargs.get("axes_locator", None))
#     505
# --> 506         self.spines = self._gen_axes_spines()
#     507
#     508         # this call may differ for non-sep axes, e.g., polar
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _gen_axes_spines(self, locations, offset, units)
#     993             ('left', mspines.Spine.linear_spine(self, 'left')),
#     994             ('right', mspines.Spine.linear_spine(self, 'right')),
# --> 995             ('bottom', mspines.Spine.linear_spine(self, 'bottom')),
#     996             ('top', mspines.Spine.linear_spine(self, 'top'))])
#     997
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/spines.py in linear_spine(cls, axes, spine_type, **kwargs)
#     499         else:
#     500             raise ValueError('unable to make path for spine "%s"' % spine_type)
# --> 501         result = cls(axes, spine_type, path, **kwargs)
#     502         result.set_visible(rcParams['axes.spines.{0}'.format(spine_type)])
#     503
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/spines.py in __init__(self, axes, spine_type, path, **kwargs)
#      50         %(Patch)s
#      51         """
# ---> 52         super(Spine, self).__init__(**kwargs)
#      53         self.axes = axes
#      54         self.set_figure(self.axes.figure)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      91         self._linewidth = 0
#      92
# ---> 93         self.set_fill(fill)
#      94         self.set_linestyle(linestyle)
#      95         self.set_linewidth(linewidth)
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/patches.py in set_fill(self, b)
#     425         """
#     426         self._fill = bool(b)
# --> 427         self._set_facecolor(self._original_facecolor)
#     428         self._set_edgecolor(self._original_edgecolor)
#     429         self.stale = True
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/patches.py in _set_facecolor(self, color)
#     303             color = mpl.rcParams['patch.facecolor']
#     304         alpha = self._alpha if self._fill else 0
# --> 305         self._facecolor = colors.to_rgba(color, alpha)
#     306         self.stale = True
#     307
#
# /opt/miniconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     159     # Special-case nth color syntax because it should not be cached.
#     160     if _is_nth_color(c):
# --> 161         from matplotlib import rcParams
#     162         prop_cycler = rcParams['axes.prop_cycle']
#     163         colors = prop_cycler.by_key().get('color', ['k'])
#
# /opt/miniconda3/lib/python3.6/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:
